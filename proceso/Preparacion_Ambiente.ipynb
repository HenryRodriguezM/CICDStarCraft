# %%
dbutils.widgets.removeAll()

# %%
# %sql
create widget text storageName default "adlStarCraft2026"

# %%
# %sql
DROP CATALOG IF EXISTS catalog_starcraft CASCADE;

# %%
# %sql
CREATE CATALOG IF NOT EXISTS catalog_starcraft;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS catalog_starcraft.raw;
CREATE SCHEMA IF NOT EXISTS catalog_starcraft.bronze;
CREATE SCHEMA IF NOT EXISTS catalog_starcraft.silver;
CREATE SCHEMA IF NOT EXISTS catalog_starcraft.golden;
